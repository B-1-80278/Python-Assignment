# %% [markdown]
# ### Consider following datasets and do PCA on each datasets.
#
# Datasets:
# wine_std.csv,
# framingham_std.csv,
# universities_std.csv,
# crime_std.csv,
# Grocery_std

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = pd.read_csv("wine_std.csv")
x
# Out:
#      Unnamed: 0      Type   Alcohol     Malic       Ash  Alcalinity  \
# 0             0 -1.213944  1.518613 -0.562250  0.232053   -1.169593
# 1             1 -1.213944  0.246290 -0.499413 -0.827996   -2.490847
# 2             2 -1.213944  0.196879  0.021231  1.109334   -0.268738
# 3             3 -1.213944  1.691550 -0.346811  0.487926   -0.809251
# 4             4 -1.213944  0.295700  0.227694  1.840403    0.451946
# ..          ...       ...       ...       ...       ...         ...
# 173         173  1.373864  0.876275  2.974543  0.305159    0.301803
# 174         174  1.373864  0.493343  1.412609  0.414820    1.052516
# 175         175  1.373864  0.332758  1.744744 -0.389355    0.151661
# 176         176  1.373864  0.209232  0.227694  0.012732    0.151661
# 177         177  1.373864  1.395086  1.583165  1.365208    1.502943
#
#      Magnesium   Phenols  Flavanoids  Nonflavanoids  Proanthocyanins  \
# 0     1.913905  0.808997    1.034819      -0.659563         1.224884
# ...

# %%
 x.drop('Unnamed: 0', axis = 1, inplace = True)
x
# Out:
#          Type   Alcohol     Malic       Ash  Alcalinity  Magnesium   Phenols  \
# 0   -1.213944  1.518613 -0.562250  0.232053   -1.169593   1.913905  0.808997
# 1   -1.213944  0.246290 -0.499413 -0.827996   -2.490847   0.018145  0.568648
# 2   -1.213944  0.196879  0.021231  1.109334   -0.268738   0.088358  0.808997
# 3   -1.213944  1.691550 -0.346811  0.487926   -0.809251   0.930918  2.491446
# 4   -1.213944  0.295700  0.227694  1.840403    0.451946   1.281985  0.808997
# ..        ...       ...       ...       ...         ...        ...       ...
# 173  1.373864  0.876275  2.974543  0.305159    0.301803  -0.332922 -0.985614
# 174  1.373864  0.493343  1.412609  0.414820    1.052516   0.158572 -0.793334
# 175  1.373864  0.332758  1.744744 -0.389355    0.151661   1.422412 -1.129824
# 176  1.373864  0.209232  0.227694  0.012732    0.151661   1.422412 -1.033684
# 177  1.373864  1.395086  1.583165  1.365208    1.502943  -0.262708 -0.392751
#
# ...

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components = 5)
pca.fit(x)
principal_component = pca.transform(x)
principal_component

df = pd.DataFrame(principal_component)


for i in range(df.shape[1]):
    x[f"PC{i}"] = df[i]
    
x
# Out:
#          Type   Alcohol     Malic       Ash  Alcalinity  Magnesium   Phenols  \
# 0   -1.213944  1.518613 -0.562250  0.232053   -1.169593   1.913905  0.808997
# 1   -1.213944  0.246290 -0.499413 -0.827996   -2.490847   0.018145  0.568648
# 2   -1.213944  0.196879  0.021231  1.109334   -0.268738   0.088358  0.808997
# 3   -1.213944  1.691550 -0.346811  0.487926   -0.809251   0.930918  2.491446
# 4   -1.213944  0.295700  0.227694  1.840403    0.451946   1.281985  0.808997
# ..        ...       ...       ...       ...         ...        ...       ...
# 173  1.373864  0.876275  2.974543  0.305159    0.301803  -0.332922 -0.985614
# 174  1.373864  0.493343  1.412609  0.414820    1.052516   0.158572 -0.793334
# 175  1.373864  0.332758  1.744744 -0.389355    0.151661   1.422412 -1.129824
# 176  1.373864  0.209232  0.227694  0.012732    0.151661   1.422412 -1.033684
# 177  1.373864  1.395086  1.583165  1.365208    1.502943  -0.262708 -0.392751
#
# ...

# %%
type(principal_component)
# Out:
# numpy.ndarray
